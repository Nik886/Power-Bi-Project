# %%
import pandas as pd

# %%
print('Hello world')
# Out:
# Hello world

# %%
import pandas as pd 
#df = pd.read_csv('Pokemon_data.csv')
#print(df.head(4))
#print(df.tail(2))
#df_ex = pd.read_excel('Test_user.xlsx')
#print (df_ex.head())
df_a = pd.read_csv('Pokemon_data.txt',sep='\t')
print(df_a)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Read Headers
print(df_a.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Read each column
print(df_a[['Name','Type 1','HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
##Read Each row
print(df_a.iloc[1:3])
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
## Read for specific location (row and column)
print(df_a.iloc[2,1])
# Out:
# Venusaur

# %%
import pandas as pd
df = pd.read_csv('Pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
for index,row in df_a.iterrows():
    print(index,row[['Name','HP']])
# Out:
# 0 Name    Bulbasaur
# HP             45
# Name: 0, dtype: object
# 1 Name    Ivysaur
# HP           60
# Name: 1, dtype: object
# 2 Name    Venusaur
# HP            80
# Name: 2, dtype: object
# 3 Name    VenusaurMega Venusaur
# HP                         80
# Name: 3, dtype: object
# 4 Name    Charmander
# HP              39
# Name: 4, dtype: object
# 5 Name    Charmeleon
# HP              58
# Name: 5, dtype: object
# 6 Name    Charizard
# HP             78
# Name: 6, dtype: object
# 7 Name    CharizardMega Charizard X
# HP                             78
# Name: 7, dtype: object
# 8 Name    CharizardMega Charizard Y
# HP                             78
# Name: 8, dtype: object
# 9 Name    Squirtle
# HP            44
# Name: 9, dtype: object
# 10 Name    Wartortle
# HP             59
# Name: 10, dtype: object
# 11 Name    Blastoise
# HP             79
# Name: 11, dtype: object
# 12 Name    BlastoiseMega Blastoise
# HP                           79
# Name: 12, dtype: object
# ...

# %%
df_a = pd.read_csv('Pokemon_data.txt',sep='\t')
print(df_a)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_a = pd.read_csv('Pokemon_data.txt')
print(df_a)
# Out:
#     #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3    3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# ..                                                 ...
# 795  719\tDiancie\tRock\tFairy\t50\t100\t150\t100\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t50\t160...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t80\t...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t80\t16...
# 799  721\tVolcanion\tFire\tWater\t80\t110\t120\t130...
#
# [800 rows x 1 columns]

# %%
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import seaborn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
print(df_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df_a)
#
# NameError: name 'df_a' is not defined

# %%
impodf_aa = pd.read_csv('Pokemon_data.txt')
print(df_aa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_aa = pd.read_csv('Pokemon_data.txt')
#       2 print(df_aa)
#
# NameError: name 'pd' is not defined

# %%
df_a
# Out:
#     #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3    3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# ..                                                 ...
# 795  719\tDiancie\tRock\tFairy\t50\t100\t150\t100\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t50\t160...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t80\t...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t80\t16...
# 799  721\tVolcanion\tFire\tWater\t80\t110\t120\t130...
#
# [800 rows x 1 columns]

# %%
df_aa
# Out:
#     #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3    3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# ..                                                 ...
# 795  719\tDiancie\tRock\tFairy\t50\t100\t150\t100\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t50\t160...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t80\t...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t80\t16...
# 799  721\tVolcanion\tFire\tWater\t80\t110\t120\t130...
#
# [800 rows x 1 columns]
